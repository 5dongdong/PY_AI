# %% [markdown]
# <a href="https://colab.research.google.com/github/5dongdong/PY_AI/blob/master/%EC%A7%80%EC%9B%90%EA%B8%88%20%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/sample_data/medical_noshow.csv')  
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df_selected = df[['Scholarship', 'Neighbourhood']]

# %%
df_selected
# Out:
#         Scholarship      Neighbourhood
# 0                 0    JARDIM DA PENHA
# 1                 0    JARDIM DA PENHA
# 2                 0      MATA DA PRAIA
# 3                 0  PONTAL DE CAMBURI
# 4                 0    JARDIM DA PENHA
# ...             ...                ...
# 110522            0        MARIA ORTIZ
# 110523            0        MARIA ORTIZ
# 110524            0        MARIA ORTIZ
# 110525            0        MARIA ORTIZ
# 110526            0        MARIA ORTIZ
#
# [110527 rows x 2 columns]

# %%
df_grouped = df.groupby('Neighbourhood')['Scholarship'].count()

# %%
df_grouped.plot(kind='bar')
plt.figure(figsize=(8, 6))

plt.show()
