# %%
import pandas as pd
import numpy  as np
from datetime import datetime 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/bitcamp/medical_noshow.csv') #csv 파일 불러오기

# %%
data #데이터 확인
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df = data

# %%
df['AppointmentDay']=pd.to_datetime(df['AppointmentDay']) #데이터 타입 변환
df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'])

# %%
df['ScheduledDay'] = df['ScheduledDay'].dt.strftime('%Y/%m/%d') #형식 변환
df['AppointmentDay'] = df['AppointmentDay'].dt.strftime('%Y/%m/%d')

# %%
df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'])#데이터 타입 변환
df['AppointmentDay']=pd.to_datetime(df['AppointmentDay'])

# %%
df['dateDifference']=df['AppointmentDay']-df['ScheduledDay'] #날짜 계산

# %%
df['dateDifference']
# Out:
# 0         0 days
# 1         0 days
# 2         0 days
# 3         0 days
# 4         0 days
#            ...
# 110522   35 days
# 110523   35 days
# 110524   41 days
# 110525   41 days
# 110526   41 days
# Name: dateDifference, Length: 110527, dtype: timedelta64[ns]

# %%
#열 값 변경

df_Test = data.loc[:, ['PatientId','Gender', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show','dateDifference']]

# %%
df_Test #변경값 확인
# Out:
#            PatientId Gender  Age      Neighbourhood  Scholarship  \
# 0       2.987250e+13      F   62    JARDIM DA PENHA            0
# 1       5.589978e+14      M   56    JARDIM DA PENHA            0
# 2       4.262962e+12      F   62      MATA DA PRAIA            0
# 3       8.679512e+11      F    8  PONTAL DE CAMBURI            0
# 4       8.841186e+12      F   56    JARDIM DA PENHA            0
# ...              ...    ...  ...                ...          ...
# 110522  2.572134e+12      F   56        MARIA ORTIZ            0
# 110523  3.596266e+12      F   51        MARIA ORTIZ            0
# 110524  1.557663e+13      F   21        MARIA ORTIZ            0
# 110525  9.213493e+13      F   38        MARIA ORTIZ            0
# 110526  3.775115e+14      F   54        MARIA ORTIZ            0
#
#         Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0                  1         0           0        0             0      No
# ...

# %%
df_Test = data.loc[:, ['PatientId','Gender', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show','dateDifference']]

# %%
df_Test['dateDifference']=df_Test['dateDifference'].dt.days #dateDifference 데이터형 변환

# %%
NoShow=df_Test.loc[:,['No-show','dateDifference']] #그래프 확인위한 변환

# %%
NoShow
# Out:
#        No-show  dateDifference
# 0           No               0
# 1           No               0
# 2           No               0
# 3           No               0
# 4           No               0
# ...        ...             ...
# 110522      No              35
# 110523      No              35
# 110524      No              41
# 110525      No              41
# 110526      No              41
#
# [110527 rows x 2 columns]

# %%
NoShow[(NoShow['No-show'] == 'No') & (NoShow['dateDifference'] == 0)]
# Out:
#        No-show  dateDifference
# 0           No               0
# 1           No               0
# 2           No               0
# 3           No               0
# 4           No               0
# ...        ...             ...
# 110511      No               0
# 110512      No               0
# 110513      No               0
# 110514      No               0
# 110517      No               0
#
# [36771 rows x 2 columns]

# %%
NoShow[(NoShow['No-show'] == 'Yes') & (NoShow['dateDifference'] == 0)]
# Out:
#        No-show  dateDifference
# 145        Yes               0
# 212        Yes               0
# 250        Yes               0
# 251        Yes               0
# 440        Yes               0
# ...        ...             ...
# 109204     Yes               0
# 109603     Yes               0
# 109856     Yes               0
# 109997     Yes               0
# 110492     Yes               0
#
# [1792 rows x 2 columns]

# %%
NoShow['dateDifference'].value_counts()
# Out:
# 0      38563
# 2       6725
# 4       5290
# 1       5213
# 7       4906
#        ...
# 82         1
# 127        1
# 126        1
# 151        1
# 123        1
# Name: dateDifference, Length: 131, dtype: int64

# %%
NoShow[NoShow['No-show'] == 'No'].value_counts()
# Out:
# No-show  dateDifference
# No       0                 36771
#          2                  5123
#          1                  4100
#          4                  4059
#          7                  3597
#                            ...
#          125                   1
#          127                   1
#          101                   1
#          82                    1
#          110                   1
# Length: 124, dtype: int64

# %%
NoShow[NoShow['No-show'] == 'No'].index.value_counts().sort_index()
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 110522    1
# 110523    1
# 110524    1
# 110525    1
# 110526    1
# Length: 88208, dtype: int64

# %%
import matplotlib.pyplot as plt

# Yes 값에 대한 그래프
counts_yes = NoShow[NoShow['No-show'] == 'Yes']['dateDifference'].value_counts().sort_index()

# No 값에 대한 그래프
counts_no = NoShow[NoShow['No-show'] == 'No']['dateDifference'].value_counts().sort_index()

# 그래프 그리기
plt.figure(figsize=(10, 30))

# Yes 값에 대한 그래프 그리기
plt.bar(counts_yes.index, counts_yes.values, color='blue', label="'No-show' column with 'Yes' value")
plt.xlabel('dateDifference')
plt.ylabel('Count')
plt.title("Value Counts of 'No-show' column with 'Yes' value, sorted by dateDifference")

# No 값에 대한 그래프 그리기
plt.bar(counts_no.index, counts_no.values, color='red', alpha=0.5, label="'No-show' column with 'No' value")
plt.xlabel('dateDifference')
plt.ylabel('Count')
plt.title("Value Counts of 'No-show' column with 'Yes' and 'No' values, sorted by dateDifference")

plt.legend()
plt.show()
